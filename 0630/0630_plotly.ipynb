# %%
import plotly
import cufflinks as cf
import pandas as pd
import numpy as np
import sys

# %%
print(sys.version)
print(plotly.__version__)
print(cf.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# 5.1.0
# 0.17.3
# 1.1.3
# 1.19.2

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
dat=np.random.randn(100,4)
df=pd.DataFrame(dat,columns=['A','B','C','D'])
print(df.shape)
df.head()
#100개의 데이터(행),4개 컬럼(열)
# Out:
# (100, 4)
#           A         B         C         D
# 0  0.366164 -0.122386 -0.466717  0.450270
# 1  1.425910  0.191923 -0.392102  1.574872
# 2 -0.550208  1.482413  0.345189  1.393104
# 3 -0.808295  0.478375 -1.142111  0.807214
# 4  1.332755  1.868663 -0.011363 -0.596955

# %%
df2 = pd.DataFrame({'items':['bag','apple','cap'],
                    'Values':[32,43,50,]})
df2
# Out:
#    items  Values
# 0    bag      32
# 1  apple      43
# 2    cap      50

# %%
df.iplot(kind='line')
# Out:
# <div>                            <div id="e5954eb8-2e6b-4830-bdc6-e0c1b26e842a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='line')
# Out:
# <div>                            <div id="9043a083-8ee3-4ad5-8816-f3347c4e3dde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
#  B, D 선 그래프를 그려보기

# %%
sel=['B','D']
df[sel].iplot(kind='line',title='제목',xTitle='x축',yTitle='y축')
# Out:
# <div>                            <div id="2fa7148b-781e-4c0f-b087-fc054bc94ad6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[ ['B', 'D'] ].iplot(kind='line')
# Out:
# <div>                            <div id="84cdb6cc-7033-4431-ba37-08ac3e2f89f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 실습 1-6(추가) iris 데이터을 불러와서 네개의 그래프를 그려보기

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.iplot(kind='line')
# Out:
# <div>                            <div id="f6a57cb2-1274-40bc-ba62-cdd69eced2d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sel=['sepal_length', 'sepal_width']
iris[sel].iplot(kind='line')
# Out:
# <div>                            <div id="fa7c8945-8867-4c39-9e00-0de11dd24463" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A',y='B',mode='markers',size=20)
# Out:
# <div>                            <div id="06451ea4-eb74-408c-b64b-619af5febf14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A',y='B',mode='lines+markers',size=20)
# Out:
# <div>                            <div id="f1186cf3-d535-4280-ac66-6fa4b06f8a38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A',y='B',mode='markers',size=20,symbol=20)
# Out:
# <div>                            <div id="57a60f06-70c7-4676-b5c6-7b507d77c3fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
#  'A', 'C'를 선택 후 산점도를 그린다. 그리고 mode 값과 size를 변경해 보면서 확인해 보자.

# %%
df[['A','C']].iplot(kind='scatter', x='A',y='C',
                        title='A,C산점도',
                        xTitle='x축:A',yTitle='y축:C',
                        mode='markers',size=7,color='lightgreen',symbol=4)
# Out:
# <div>                            <div id="f22f20af-9cef-4621-b4ea-b280686ba8aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.head()
# Out:
#    items  Values
# 0    bag      32
# 1  apple      43
# 2    cap      50

# %%
df2.iplot(kind='bar',x='items',y='Values')
#바플롯은 x축에 범주형
# Out:
# <div>                            <div id="0498df1c-352c-4ce2-8d95-89849e3c9fff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
iris.iplot(kind='bar',x='species',y='sepal_length')
# Out:
# <div>                            <div id="b8092138-e371-4fa7-a0e6-3675ef9e6263" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# * iris 데이터 셋의 sepal_width와 petal_length에 대해서 막대그래프 그려보기
#  * x축, y축, 제목을 달아주세요.
#  * 그래프를 보고 .. 한줄 코멘트 달아주기.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.iplot(kind='bar',x='sepal_width',y='petal_length',
          xTitle='sepal_width',yTitle='petal_length',
          title='petal_length per sepal_width',color='green')
# Out:
# <div>                            <div id="f71f574f-55a5-44d7-8d79-a967d8a1b6eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# 해석:꽃받침 폭이 3에 가까울수록 꽃잎의 길이가 길어진다.

# %% [markdown]
# * iris 데이터 셋의 네 개의 컬럼의 평균에 대해서 막대그래프 그려보기
#  * x축, y축, 제목을 달아주세요.
#  * 그래프를 보고 .. 한줄 코멘트 달아주기.

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sel=iris.mean()
sel
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
iris.mean().iplot(kind='scatter')
# Out:
# <div>                            <div id="b67e7d9b-4011-44b2-b7a7-51f04057bf64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
iris['mean_val']=iris.iloc[:,0:4].mean(axis=1)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  mean_val
# 0             5.1          3.5           1.4          0.2     setosa     2.550
# 1             4.9          3.0           1.4          0.2     setosa     2.375
# 2             4.7          3.2           1.3          0.2     setosa     2.350
# 3             4.6          3.1           1.5          0.2     setosa     2.350
# 4             5.0          3.6           1.4          0.2     setosa     2.550
# ..            ...          ...           ...          ...        ...       ...
# 145           6.7          3.0           5.2          2.3  virginica     4.300
# 146           6.3          2.5           5.0          1.9  virginica     3.925
# 147           6.5          3.0           5.2          2.0  virginica     4.175
# 148           6.2          3.4           5.4          2.3  virginica     4.325
# 149           5.9          3.0           5.1          1.8  virginica     3.950
#
# [150 rows x 6 columns]

# %%
iris.iplot(kind='bar',x='species',y='mean_val')
# Out:
# <div>                            <div id="17acc34c-5788-4536-860f-005ba5f4a98b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
iris.iplot(kind='bar', x='species', y=['sepal_width','sepal_length','petal_width','petal_length'], xTitle='Species', yTitle = 'S&P')
# Out:
# <div>                            <div id="3af6867b-3845-41f6-8e47-1e708c98cd2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df = pd.DataFrame(np.random.rand(10,3),
                  columns=['A', 'B', 'C'])
df.head()
# Out:
#           A         B         C
# 0  0.020222  0.597596  0.660493
# 1  0.187548  0.267199  0.155032
# 2  0.274103  0.739744  0.141450
# 3  0.872195  0.693770  0.850210
# 4  0.876014  0.988565  0.485635

# %%
df['A'].iplot(kind='bar')
# Out:
# <div>                            <div id="509fe335-e48f-49c0-b0d8-386fc33870b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>                            <div id="cc114fbf-f8f6-42bb-84ce-0f80715e0eda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar', barmode='stack')
# Out:
# <div>                            <div id="5da40b46-25a0-49b3-a0e2-8bf040286610" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='barh', barmode='stack')
# Out:
# <div>                            <div id="e6b9a9dc-4e10-45cb-801a-329e95fd9dc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="b2b71e13-ca61-4455-b6c9-62c1cbab8c10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],
 'y':[10,20,30,40,60],
 'z':[5,4,3,2,1]})
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  40  2
# 4  5  60  1

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="c7154b48-5db1-46c8-8023-ff2b011767d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df = cf.datagen.lines()  
df.shape
# Out:
# (100, 5)

# %%
df
# Out:
#               LZO.TO    UFN.VA    TVG.QI    ENB.ZP    GJY.UX
# 2015-01-01 -2.535945 -0.593559 -1.636026 -0.352969  0.335469
# 2015-01-02 -2.215278 -1.206648 -2.363956  0.995081  1.068730
# 2015-01-03 -2.363804 -2.255014 -3.090777  0.393124  1.514347
# 2015-01-04 -2.784556 -3.200334 -1.543827 -0.331850  2.054440
# 2015-01-05 -1.548274 -3.889248 -1.109060 -0.241341  2.105669
# ...              ...       ...       ...       ...       ...
# 2015-04-06 -6.725743 -4.751788 -6.116236  2.039479 -3.153641
# 2015-04-07 -5.313737 -3.827676 -5.695642  1.765879 -2.617391
# 2015-04-08 -5.865992 -2.986783 -4.442164  2.066043 -1.521241
# 2015-04-09 -6.084362 -4.315638 -4.389528  2.023668 -1.759063
# 2015-04-10 -6.271646 -3.392187 -5.759012  2.335951 -5.233182
#
# [100 rows x 5 columns]

# %%
df.iplot(kind='line')
# Out:
# <div>                            <div id="92e04e2d-353c-42d7-83fd-d52d79632338" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
themes = cf.getThemes()
themes
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
data = pd.Series(range(10))
for theme in themes:
 data.iplot(kind='bar', theme=theme, title=theme)
# Out:
# <div>                            <div id="197621ab-610c-4621-bc5d-7436fd4425e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

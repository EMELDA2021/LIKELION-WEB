# %%
import pandas as pd
import numpy as np
import folium
from folium import plugins

# %%
corona_hospital = pd.read_csv("./corona_hospital.csv", encoding="EUCKR")
corona_hospital.info()
corona_hospital.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-0d1e9fbb7f7c> in <module>
# ----> 1 corona_hospital = pd.read_csv("./corona_hospital.csv", encoding="EUCKR")
#       2 corona_hospital.info()
#       3 corona_hospital.isnull().sum()
#
# ...

# %%
yaksuteo = yaksuteo.dropna(axis=0, subset=["약수터명", "위도", "경도"])

# %%
yaksuteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1314 entries, 0 to 1471
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   약수터명      1314 non-null   object
#  1   소재지도로명주소  289 non-null    object
#  2   소재지지번주소   1304 non-null   object
#  3   위도        1314 non-null   float64
#  4   경도        1314 non-null   float64
#  5   지정일자      597 non-null    object
#  6   일평균이용인구수  1314 non-null   int64
#  7   수질검사일자    1314 non-null   object
#  8   수질검사결과구분  1314 non-null   object
#  9   부적합항목     535 non-null    object
#  10  관리기관전화번호  1314 non-null   object
#  11  관리기관명     1314 non-null   object
#  12  데이터기준일자   1314 non-null   object
#  13  제공기관코드    1314 non-null   int64
#  14  제공기관명     1314 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 164.2+ KB

# %%
yaksuteo = yaksuteo.loc[:, ["약수터명", "위도", "경도", "일평균이용인구수"]]

# %%
yaksu_map = folium.Map(location=[37.5665, 126.9780])

yaksu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
name_of_yaksu = yaksuteo.loc[:,"약수터명"]
name_of_yaksu = name_of_yaksu.to_numpy()
type(name_of_yaksu)
# Out:
# numpy.ndarray

# %%
temp = np.array(zip(yaksuteo["위도"], yaksuteo["경도"]))
# Out:
# array(<zip object at 0x7fe7ed5e4820>, dtype=object)

# %%
geocodes = np.array(list(zip(yaksuteo["위도"], yaksuteo["경도"])))
geocodes
# Out:
# array([[ 37.46227725, 126.772928  ],
#        [ 37.468825  , 126.732545  ],
#        [ 37.46883023, 126.7242531 ],
#        ...,
#        [ 37.364565  , 126.889788  ],
#        [ 37.372041  , 126.897731  ],
#        [ 37.604114  , 127.085838  ]])

# %%
plugins.MarkerCluster(geocodes, popups=name_of_yaksu).add_to(yaksu_map)

# %%
yaksu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
import pandas as pd

# %%
train=pd.read_csv("../california_housing_train.csv")
test=pd.read_csv("../california_housing_test.csv")

# %%
train.shape, test.shape
# Out:
# ((17000, 9), (3000, 9))

# %%
train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
train.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %% [markdown]
# - longitude:주택이 서쪽으로 얼마나 가야 있는지 측정한 값(값이 높을수록 더 서쪽에 있음)
# - latitude: 주택이 북쪽으로 얼마나 가야 있는지 측정한 값(값이 높을수록 더 북쪽에 있음)
# - housingMedianAge: 블록 내 주택의 연령 중앙값(값이 낮을 수록 새 건물임)
# - totalRooms: 블록 내 주택의 총 방 개수
# - totalBedrooms: 블록 내 주택의 총 침실 수
# - population: 블록 내 거주 중인 총 주민 수
# - households: 블록 내 총가구(한 세대에 거주하는 그룹) 수
# - medianIncome: 블록 내 가구의 소득 중앙값(단위: 미화 10,000달러)
# - medianHouseValue: 블록 내 가구의 주택 매매가 중앙값(단위: 미국 달러)

# %%
train.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
train.hist(bins=50, figsize=(20,15)) #bins막대기의 너비
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train.plot(kind='scatter',x='longitude',y='latitude',alpha=0.1,
          s=train['population']/100, c='median_house_value',
          cmap=plt.get_cmap('jet'),
          figsize=(12,8))
#알파값을 이용해서 빈도수를 보일수 있게한다.train자료는 만칠천개
#s는 점의 size, c는 점의 color 
#위도와 경도로 작성되었기 때문에 캘리포니아 지도와 같다
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
sel=['total_rooms','total_bedrooms','population']
temp_train = train[ sel ]
print("데이터 가공 셋의 크기 : ", temp_train.shape)
print("데이터 가공 셋의 일부 : ", temp_train.head())
# Out:
# 데이터 가공 셋의 크기 :  (17000, 3)
# 데이터 가공 셋의 일부 :     total_rooms  total_bedrooms  population
# 0       5612.0          1283.0      1015.0
# 1       7650.0          1901.0      1129.0
# 2        720.0           174.0       333.0
# 3       1501.0           337.0       515.0
# 4       1454.0           326.0       624.0

# %%
temp_train.describe()
# Out:
#         total_rooms  total_bedrooms    population
# count  17000.000000    17000.000000  17000.000000
# mean    2643.664412      539.410824   1429.573941
# std     2179.947071      421.499452   1147.852959
# min        2.000000        1.000000      3.000000
# 25%     1462.000000      297.000000    790.000000
# 50%     2127.000000      434.000000   1167.000000
# 75%     3151.250000      648.250000   1721.000000
# max    37937.000000     6445.000000  35682.000000

# %% [markdown]
# 2-3 37937의 위치와 정보 얻기

# %%
train['total_rooms'].idxmax()
# Out:
# 2871

# %%
train.iloc[2871,:]
# Out:
# longitude               -117.7400
# latitude                  33.8900
# housing_median_age         4.0000
# total_rooms            37937.0000
# total_bedrooms          5471.0000
# population             16122.0000
# households              5189.0000
# median_income              7.4947
# median_house_value    366300.0000
# Name: 2871, dtype: float64

# %%
max_room_info=train.loc[train['total_rooms']==37937, :]
max_room_info
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2871    -117.74     33.89                 4.0      37937.0          5471.0
#
#       population  households  median_income  median_house_value
# 2871     16122.0      5189.0         7.4947            366300.0

# %%
max_bedroom_info=train.loc[train['total_bedrooms']==6445, :]
max_bedroom_info
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12772    -121.79     36.64                11.0      32627.0          6445.0
#
#        population  households  median_income  median_house_value
# 12772     28566.0      6082.0         2.3087            118800.0

# %%
import seaborn as sns

# %%
fig=plt.figure(figsize=(12,8))

plt.subplot(3,1,1)
sns.boxplot(x='total_rooms',data=temp_train)
plt.subplot(3,1,2)
sns.boxplot(x='total_bedrooms',data=temp_train)
plt.subplot(3,1,3)
sns.boxplot(x='population',data=temp_train)
#값의 밀집도 알수있음. 점은 이상치(특이치)
# Out:
# <AxesSubplot:xlabel='population'>

# %%
fig=plt.figure(figsize=(12,8))

plt.subplot(3,1,1)
sns.histplot(x='total_rooms',data=temp_train)
plt.subplot(3,1,2)
sns.histplot(x='total_bedrooms',data=temp_train)
plt.subplot(3,1,3)
sns.histplot(x='population',data=temp_train)
#수치형 자료는 box,hist사용
# Out:
# <AxesSubplot:xlabel='population', ylabel='Count'>

# %%
sns.pairplot(temp_train)
#sns.pairplot(데이터프레임명)
#같은 변수끼리는 히스토그램으로 나타나며 나머지는 모두 산점도형태로. 
#따라서 선형성을 띄는 변수들은 한눈에 확인하여 상관관계 파악가능

# %%
temp_train.corr()
# Out:
#                 total_rooms  total_bedrooms  population
# total_rooms        1.000000        0.928403    0.860170
# total_bedrooms     0.928403        1.000000    0.881169
# population         0.860170        0.881169    1.000000

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,3,1) 
sns.boxplot(x="total_rooms", data=train)
plt.subplot(3,3,2) 
sns.boxplot(x="total_bedrooms", data=train)
plt.subplot(3,3,3) 
sns.boxplot(x="population", data=train) 
plt.subplot(3,3,4) 
sns.boxplot(x="longitude", data=train)
plt.subplot(3,3,5) 
sns.boxplot(x="latitude", data=train)
plt.subplot(3,3,6) 
sns.boxplot(x="households", data=train) 
plt.subplot(3,3,7) 
sns.boxplot(x="median_income", data=train)
plt.subplot(3,3,8) 
sns.boxplot(x="median_house_value", data=train)
# Out:
# <AxesSubplot:xlabel='median_house_value'>

# %% [markdown]
# 2-3 for문으로 시각화 해보기

# %%
plt.figure(figsize=(10,10))
for i in range(1,9):
    plt.subplot(3,3,i)
    sns.boxplot(x=train.columns[i], data = train)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1) 
sns.boxplot(x="median_income", data=train)
plt.subplot(2,2,2) 
sns.boxplot(x="median_house_value", data=train)
plt.subplot(2,2,3) 
sns.boxplot(x="total_rooms", data=train)
plt.subplot(2,2,4) 
sns.boxplot(x="total_bedrooms", data=train)
# Out:
# <AxesSubplot:xlabel='total_bedrooms'>

# %%
temp02 = train.loc[:, [ "median_income", "median_house_value" ] ]
temp02.head()
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
## 두 컬럼 선택 8열, 9열
temp03= train.iloc[:, [7, 8] ]
print( temp03.head() )
temp03= train.iloc[:, [-2, -1] ]
print( temp03.head() )
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0

# %% [markdown]
# # 조건을 이용하여 데이터 그룹을 시켜보자.

# %%
train.total_rooms.describe()
# Out:
# count    17000.000000
# mean      2643.664412
# std       2179.947071
# min          2.000000
# 25%       1462.000000
# 50%       2127.000000
# 75%       3151.250000
# max      37937.000000
# Name: total_rooms, dtype: float64

# %%
#Group01 3151~
#Group02 2127~3150
#Group03 1462~2127
#Group04 ~1462

# %%
tmp_A1=train.loc[train['total_rooms']>=3151,:]
tmp_A2=train.loc[(train['total_rooms']>=2127)&(train['total_rooms']<3151),:]
tmp_A3=train.loc[(train['total_rooms']>=1462)&(train['total_rooms']<2127),:]
tmp_A4=train.loc[train['total_rooms']<1462,:]

tmp_A1.shape,tmp_A2.shape,tmp_A3.shape,tmp_A4.shape
# Out:
# ((4251, 9), (4257, 9), (4247, 9), (4245, 9))

# %%
train.loc[train['total_rooms']>=3151,"room_level"]=1
train.loc[(train['total_rooms']>=2127)&(train['total_rooms']<3151),'room_level']=2
train.loc[(train['total_rooms']>=1462)&(train['total_rooms']<2127),'room_level']=3
train.loc[train['total_rooms']<1462,'room_level']=4
#train.loc[행,열]=1 행과 열을 지정하고 등급값넣기
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
train['room_level'].isnull().sum()
# Out:
# 0

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'room_level'],
#       dtype='object')

# %% [markdown]
# # 실습: 테스트 셋도 그룹나누기

# %%
test.total_rooms.describe()
# Out:
# count     3000.000000
# mean      2599.578667
# std       2155.593332
# min          6.000000
# 25%       1401.000000
# 50%       2106.000000
# 75%       3129.000000
# max      30450.000000
# Name: total_rooms, dtype: float64

# %%
#Group01 3129~
#Group02 2106~3129
#Group03 1401~2106
#Group04 ~1401
#그런데 train과 test의 기준값은 동일하게.
#Group01 3151~
#Group02 2127~3150
#Group03 1462~2127
#Group04 ~1462

# %%
tmp_A1_=test.loc[test['total_rooms']>=3151,:]
tmp_A2_=test.loc[(test['total_rooms']>=2127)&(test['total_rooms']<3151),:]
tmp_A3_=test.loc[(test['total_rooms']>=1462)&(test['total_rooms']<2127),:]
tmp_A4_=test.loc[test['total_rooms']<1462,:]

tmp_A1_.shape,tmp_A2_.shape,tmp_A3_.shape,tmp_A4_.shape
# Out:
# ((742, 9), (745, 9), (688, 9), (825, 9))

# %%
test.loc[test['total_rooms']>=3151,"room_level"]=1
test.loc[(test['total_rooms']>=2127)&(test['total_rooms']<3151),'room_level']=2
test.loc[(test['total_rooms']>=1462)&(test['total_rooms']<2127),'room_level']=3
test.loc[test['total_rooms']<1401,'room_level']=4
#train.loc[행,열]=1 행과 열을 지정하고 등급값넣기
test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
test['room_level'].isnull().sum()
# Out:
# 78

# %%
test.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'room_level'],
#       dtype='object')

# %% [markdown]
#  (추가) total_bedromms으로 동일하게 그룹화 해 보기.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          17000 non-null  float64
# dtypes: float64(10)
# memory usage: 1.3 MB

# %%
train['room_level']=train.room_level.astype('category')
train.info()
#수치형에서 범주형(category)으로 바꾸기 > 범주형 그래프 그리기위해서
#dtype: int62,float62,object,bool(참과거짓),datetime64(날짜와시간),category
#.set_categories([],ordered=True):레벨의 순서정해줌
#>카테고리에 순서에 지정하면 sorting 및 min/max는 어휘 순서 대신 논리 순서를 사용
#.sort_values(inplace=True): 레벨의 순서 확인가능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          17000 non-null  category
# dtypes: category(1), float64(9)
# memory usage: 1.2 MB

# %%
sns.boxplot(x='room_level',y='housing_median_age',data=train)
# Out:
# <AxesSubplot:xlabel='room_level', ylabel='housing_median_age'>

# %% [markdown]
#  - 최신건물일수록(age낮을수록),방수가 많다(룸레벨 낮을수록)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          17000 non-null  category
# dtypes: category(1), float64(9)
# memory usage: 1.2 MB

# %% [markdown]
# # 룸레벨과 다른 요소와 관계

# %%
train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'room_level'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
for i in range(1,9):
    plt.subplot(4,2,i)
    sns.boxplot(x='room_level',y=train.columns[i], data = train)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(1,9):
    plt.subplot(4,2,i)
    sns.boxplot(y='room_level',x=train.columns[i], data = train)
plt.show()

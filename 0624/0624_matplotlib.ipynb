# %%
import matplotlib.pyplot as plt #그림그려주는역할
import matplotlib #폰트설정 등 기능하는 역할
import seaborn as sns

# %%
print(matplotlib.__version__)
# Out:
# 3.3.2

# %%
plt.plot([1,2,3,4,5], 'o')  
# plot()는 포인트(마커)를 그리는데 사용.
#subplot(행,열,순서)j는 figure의 레이아웃을 설명하는 3개인수와 사용.
#'-' 선 : 기본값
#x값 생략가능. y축에 맞게 설정됨
plt.show()

# %%
import numpy as np

# %%
n_list=np.array([1,2,3,4,5])
sns.countplot(n_list)
plt.show()
# Out:
# C:\Users\ahah0\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x=range(0,100)
y=range(0,200,2)
plt.plot(x,y,'o')
plt.show()

# %%
import numpy as np
ypoints=np.array([3,3,1,20,10])
ypoints_list=[3,3,1,20,10]

plt.plot(ypoints,marker='o')
plt.show()

# %%
plt.plot(ypoints,marker='4')
plt.show()

# %%
y = np.array([3, 8, 1, 10])
plt.plot(y, '^--r') #fmt(마커,라인,컬러):^:b
plt.show()

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15)#ms:markersize
plt.show()

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15, mec = 'r')#mec:markeredgecolor:가장자리색지정
plt.show()

# %%
plt.plot(y , marker = 'o', ms=15, mfc = 'r')#mfc:markerfacecolor:마커 내부색상
plt.show()

# %%
y = np.array([3, 8, 1, 12, 5])
plt.plot(y, linewidth = '12.5')

# %% [markdown]
# 03 여러 개의 그래프 그리기

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2) 
plt.show()

# %% [markdown]
# 3X3(3열3행)의 객체

# %%
fig=plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(3,3,1) 
ax2 = fig.add_subplot(3,3,2) 
ax3 = fig.add_subplot(3,3,3) 
ax4 = fig.add_subplot(3,3,4) 
ax5 = fig.add_subplot(3,3,5) 
ax6 = fig.add_subplot(3,3,6) 
ax7 = fig.add_subplot(3,3,7) 
ax8 = fig.add_subplot(3,3,8) 
ax9 = fig.add_subplot(3,3,9) 
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,3,1) # 1행 3열 의 것중에 첫번째
ax2 = fig.add_subplot(1,3,2) # 1행 3열 의 것중에 두번째
ax3 = fig.add_subplot(1,3,3) # 1행 3열 의 것중에 두번째
plt.show()

# %%
### plot, bar 그래프 그리기
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
x=range(0,100)
y=[v*v for v in x]
ax1.plot(x,y)
ax2.bar(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2 * np.pi, 0.1)
#arange(시작값,종료값,증감값)
#np.pi: pi는 원주율(상수)
sin_y = np.sin(x)
cos_y = np.cos(x)
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')
plt.show()

# %% [markdown]
# 실습:sin,cos,tan,tanh 2x2그래프로 그려보기

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2 * np.pi, 0.1)

sin_y = np.sin(x)
cos_y = np.cos(x)
tan_y = np.tan(x)
tanh_y= np.tanh(x)

fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')
ax3.plot(x, tan_y, 'y--')
ax4.plot(x, tanh_y, 'g--')

plt.show()

# %% [markdown]
# 함수식만 넣어서 그래프그리기

# %%
x=np.arange(0.0, 2*np.pi, 0.1)
plt.plot(x,np.sin(x))

# %%
x=np.arange(0.0, 2*np.pi, 0.1)
f_x=x**2
plt.plot(x,f_x)

# %% [markdown]
# 범례넣기

# %%
x = np.arange(10)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.plot(x, 2*x, label='y = %ix' % 2)
plt.legend()
plt.show()

# %%
for i in range(5):
     plt.plot(x, i*x, label='y = %ix' % i)
plt.legend()
plt.show()

# %% [markdown]
# 범례 위치지정(loc)

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='upper left')    # 2
plt.subplot(3,3,2)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='upper center')  # 9
plt.subplot(3,3,3)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='upper right')  # 1
plt.subplot(3,3,4)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='center left')  # 6
plt.subplot(3,3,5)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='center')  # 10
plt.subplot(3,3,6)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='center right')  # 5
plt.subplot(3,3,7)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='lower left')  # 3
plt.subplot(3,3,8)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='lower center')  # 8
plt.subplot(3,3,9)
plt.plot(x, 1*x, label='y = %ix' % 1)
plt.legend(loc='lower right')  # 4

# %%
import os, warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# 폰트가 깨지는 문제가 생길때

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("스포츠 시청 데이터")
plt.xlabel("평균 혈압")
plt.ylabel("칼로리")
# Out:
# Text(0, 0.5, '칼로리')

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import platform

# %%
path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
     font_name = font_manager.FontProperties(fname=path).get_name()
     rc('font', family=font_name)
elif platform.system()=="Darwin":
     rc('font', family='AppleGothic')
else:
     print("Unknown System")
 
matplotlib.rcParams['axes.unicode_minus'] = False 
#마이너스 값 표시여부(true:표시,false:미표시)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("스포츠 시청 데이터")
plt.xlabel("평균 혈압")
plt.ylabel("칼로리")
# Out:
# Text(0, 0.5, '칼로리')

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# 상관관계

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = np.array([51,71,18,17,21,17,2,9,4,11,12,9,6]) 
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
x = np.array([51,71,18,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='hotpink')
x = np.array([511,711,118,17,21,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color='#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(10, size=10) #임의의 정수만들기
print(len(x), type(x),x)
y = np.random.randint(80,100, size=10)
print(len(y), type(y),y)

colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar() # colormap 을 포함할 수 있다.
plt.show()
# Out:
# 10 <class 'numpy.ndarray'> [1 7 7 2 0 5 2 4 8 8]
# 10 <class 'numpy.ndarray'> [91 99 83 99 92 89 93 85 97 87]

# %% [markdown]
# 투명도(alpha):

# %%
x = np.random.randint(10, size=10)
y = np.random.randint(80,100, size=10)
sizes = np.random.randint(20,800, size=10)
colors = np.random.randint(0,100, size=10)
plt.scatter(x, y, s=sizes, alpha=0.6)

# %%
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([30,20,40,90])
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([30,20,40,90])
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y, color = 'hotpink')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x, y, width=0.2, color = 'hotpink')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y, height=0.5, color = 'hotpink')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# 막대그래프와 히스토그래프의 차이점?
#  - x축-히스토그램:수치형, 막대그래프:범주형
#  - 막대간격

# %%
value=np.random.randint(20,800,size=100)
plt.hist(value)
# Out:
# (array([12., 17.,  9.,  8.,  9.,  7., 12., 12., 10.,  4.]),
#  array([ 42. , 117.6, 193.2, 268.8, 344.4, 420. , 495.6, 571.2, 646.8,
#         722.4, 798. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np

# %%
xAxis=np.linspace(0,100,5)
print(xAxis)
# Out:
# [  0.  25.  50.  75. 100.]

# %% [markdown]
# 행렬곱

# %%
a=np.array([[1,2],
           [3,4]])
b=np.array([[2,3],
           [4,5]])

# %%
print(np.dot(a,b)) #내적
# Out:
# [[10 13]
#  [22 29]]

# %%
print(np.outer(a,b)) #외적
# Out:
# [[ 2  3  4  5]
#  [ 4  6  8 10]
#  [ 6  9 12 15]
#  [ 8 12 16 20]]

# %% [markdown]
# 파이썬이 각광받는이유: 데이터처리속도,효율성

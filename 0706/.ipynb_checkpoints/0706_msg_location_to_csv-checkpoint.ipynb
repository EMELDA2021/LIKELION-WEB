# %%
import pandas as pd
from datetime import datetime
import os

# %% [markdown]
# ### 재난문자 location_id > 거리두기7구역으로 나누기

# %%
msg_location=pd.read_csv('../msg_location_id.csv',engine ='python', encoding='EUCKR')

# %%
msg_location.head()
# Out:
#    LOCATION_ID 발송지역(시도) 발송지역(시군구)       법정동코드 법정동(시도) 법정동(시군구)
# 0            2      강원도        전체  4200000000     강원도      NaN
# 1            3      강원도       강릉시  4215000000     강원도      강릉시
# 2            4      강원도       고성군  4282000000     강원도      고성군
# 3            5      강원도       동해시  4217000000     강원도      동해시
# 4            6      강원도       삼척시  4223000000     강원도      삼척시

# %%
msg_location.columns
# Out:
# Index(['LOCATION_ID', '발송지역(시도)', '발송지역(시군구)', '법정동코드', '법정동(시도)', '법정동(시군구)'], dtype='object')

# %%
msg_location=msg_location.drop(['발송지역(시군구)','법정동코드','법정동(시도)','법정동(시군구)'],axis=1)
msg_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LOCATION_ID  253 non-null    int64
#  1   발송지역(시도)     253 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.1+ KB

# %%
msg_location.head()
# Out:
#    LOCATION_ID 발송지역(시도)
# 0            2      강원도
# 1            3      강원도
# 2            4      강원도
# 3            5      강원도
# 4            6      강원도

# %%
msg_location['Area']=msg_location['발송지역(시도)']
msg_location.head()
# Out:
#    LOCATION_ID 발송지역(시도) Area
# 0            2      강원도  강원도
# 1            3      강원도  강원도
# 2            4      강원도  강원도
# 3            5      강원도  강원도
# 4            6      강원도  강원도

# %%
msg_location['Area'].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도', '충청남도',
#        '충청북도', '세종특별자치시', '임진강 수계지역(경기도 연천군,파주시)'], dtype=object)

# %%
msg_location['Area']=msg_location['Area'].replace(['서울특별시','경기도','임진강 수계지역(경기도 연천군,파주시)','인천광역시'],'수도권')
msg_location['Area']=msg_location['Area'].replace(['대전광역시','세종특별자치시','충청북도','충청남도'],'충청권')
msg_location['Area']=msg_location['Area'].replace(['광주광역시','전라북도','전라남도'],'호남권')
msg_location['Area']=msg_location['Area'].replace(['대구광역시','경상북도'],'경북권')
msg_location['Area']=msg_location['Area'].replace(['부산광역시','울산광역시','경상남도'],'경남권')
msg_location['Area']=msg_location['Area'].replace(['강원도'],'강원권')
msg_location['Area']=msg_location['Area'].replace(['제주특별자치도'],'제주')

# %%
msg_location.isnull().sum()
# Out:
# LOCATION_ID    0
# 발송지역(시도)       0
# Area           0
# dtype: int64

# %%
msg_location
# Out:
#      LOCATION_ID               발송지역(시도) Area
# 0              2                    강원도  강원권
# 1              3                    강원도  강원권
# 2              4                    강원도  강원권
# 3              5                    강원도  강원권
# 4              6                    강원도  강원권
# 5              7                    강원도  강원권
# 6              8                    강원도  강원권
# 7              9                    강원도  강원권
# 8             10                    강원도  강원권
# 9             11                    강원도  강원권
# 10            12                    강원도  강원권
# 11            13                    강원도  강원권
# 12            14                    강원도  강원권
# 13            15                    강원도  강원권
# 14            16                    강원도  강원권
# 15            17                    강원도  강원권
# 16            18                    강원도  강원권
# 17            19                    강원도  강원권
# 18            20                    강원도  강원권
# 19            21                    경기도  수도권
# 20            22                    경기도  수도권
# 21            23                    경기도  수도권
# 22            24                    경기도  수도권
# 23            25                    경기도  수도권
# 24            26                    경기도  수도권
# 25            27                    경기도  수도권
# 26            28                    경기도  수도권
# 27            29                    경기도  수도권
# 28            30                    경기도  수도권
# 29            31                    경기도  수도권
# 30            32                    경기도  수도권
# 31            33                    경기도  수도권
# 32            34                    경기도  수도권
# 33            35                    경기도  수도권
# 34            36                    경기도  수도권
# 35            37                    경기도  수도권
# 36            38                    경기도  수도권
# 37            39                    경기도  수도권
# 38            40                    경기도  수도권
# 39            41                    경기도  수도권
# 40            42                    경기도  수도권
# 41            43                    경기도  수도권
# 42            44                    경기도  수도권
# 43            45                    경기도  수도권
# 44            46                    경기도  수도권
# 45            47                    경기도  수도권
# 46            48                    경기도  수도권
# 47            49                    경기도  수도권
# 48            50                    경기도  수도권
# 49            51                    경기도  수도권
# 50            52                    경기도  수도권
# 51            53                   경상남도  경남권
# 52            54                   경상남도  경남권
# 53            55                   경상남도  경남권
# 54            56                   경상남도  경남권
# 55            57                   경상남도  경남권
# 56            58                   경상남도  경남권
# 57            60                   경상남도  경남권
# 58            61                   경상남도  경남권
# 59            62                   경상남도  경남권
# 60            63                   경상남도  경남권
# 61            64                   경상남도  경남권
# 62            65                   경상남도  경남권
# 63            67                   경상남도  경남권
# 64            68                   경상남도  경남권
# 65            68                   경상남도  경남권
# 66            68                   경상남도  경남권
# 67            68                   경상남도  경남권
# 68            68                   경상남도  경남권
# 69            68                   경상남도  경남권
# 70            69                   경상남도  경남권
# 71            70                   경상남도  경남권
# 72            71                   경상남도  경남권
# 73            72                   경상남도  경남권
# 74            73                   경상남도  경남권
# 75            74                   경상북도  경북권
# 76            75                   경상북도  경북권
# 77            76                   경상북도  경북권
# 78            77                   경상북도  경북권
# 79            78                   경상북도  경북권
# 80            79                   경상북도  경북권
# 81            80                   경상북도  경북권
# 82            81                   경상북도  경북권
# 83            82                   경상북도  경북권
# 84            83                   경상북도  경북권
# 85            84                   경상북도  경북권
# 86            85                   경상북도  경북권
# 87            86                   경상북도  경북권
# 88            87                   경상북도  경북권
# 89            88                   경상북도  경북권
# 90            89                   경상북도  경북권
# 91            90                   경상북도  경북권
# 92            91                   경상북도  경북권
# 93            92                   경상북도  경북권
# 94            93                   경상북도  경북권
# 95            94                   경상북도  경북권
# 96            95                   경상북도  경북권
# 97            96                   경상북도  경북권
# 98            97                   경상북도  경북권
# 99            98                  광주광역시  호남권
# 100           99                  광주광역시  호남권
# 101          100                  광주광역시  호남권
# 102          101                  광주광역시  호남권
# 103          102                  광주광역시  호남권
# 104          103                  광주광역시  호남권
# 105          104                  대구광역시  경북권
# 106          105                  대구광역시  경북권
# 107          106                  대구광역시  경북권
# 108          107                  대구광역시  경북권
# 109          108                  대구광역시  경북권
# 110          109                  대구광역시  경북권
# 111          110                  대구광역시  경북권
# 112          111                  대구광역시  경북권
# 113          112                  대구광역시  경북권
# 114          113                  대전광역시  충청권
# 115          114                  대전광역시  충청권
# 116          115                  대전광역시  충청권
# 117          116                  대전광역시  충청권
# 118          117                  대전광역시  충청권
# 119          118                  대전광역시  충청권
# 120          119                  부산광역시  경남권
# 121          120                  부산광역시  경남권
# 122          121                  부산광역시  경남권
# 123          122                  부산광역시  경남권
# 124          123                  부산광역시  경남권
# 125          124                  부산광역시  경남권
# 126          125                  부산광역시  경남권
# 127          126                  부산광역시  경남권
# 128          127                  부산광역시  경남권
# 129          128                  부산광역시  경남권
# 130          129                  부산광역시  경남권
# 131          130                  부산광역시  경남권
# 132          131                  부산광역시  경남권
# 133          132                  부산광역시  경남권
# 134          133                  부산광역시  경남권
# 135          134                  부산광역시  경남권
# 136          135                  부산광역시  경남권
# 137          136                  서울특별시  수도권
# 138          137                  서울특별시  수도권
# 139          138                  서울특별시  수도권
# 140          139                  서울특별시  수도권
# 141          140                  서울특별시  수도권
# 142          141                  서울특별시  수도권
# 143          142                  서울특별시  수도권
# 144          143                  서울특별시  수도권
# 145          144                  서울특별시  수도권
# 146          145                  서울특별시  수도권
# 147          146                  서울특별시  수도권
# 148          147                  서울특별시  수도권
# 149          148                  서울특별시  수도권
# 150          149                  서울특별시  수도권
# 151          150                  서울특별시  수도권
# 152          151                  서울특별시  수도권
# 153          152                  서울특별시  수도권
# 154          153                  서울특별시  수도권
# 155          154                  서울특별시  수도권
# 156          155                  서울특별시  수도권
# 157          156                  서울특별시  수도권
# 158          157                  서울특별시  수도권
# 159          158                  서울특별시  수도권
# 160          159                  서울특별시  수도권
# 161          160                  서울특별시  수도권
# 162          161                  서울특별시  수도권
# 163          162                  울산광역시  경남권
# 164          163                  울산광역시  경남권
# 165          164                  울산광역시  경남권
# 166          165                  울산광역시  경남권
# 167          166                  울산광역시  경남권
# 168          167                  울산광역시  경남권
# 169          168                  인천광역시  수도권
# 170          169                  인천광역시  수도권
# 171          170                  인천광역시  수도권
# 172          171                  인천광역시  수도권
# 173          172                  인천광역시  수도권
# 174          173                  인천광역시  수도권
# 175          174                  인천광역시  수도권
# 176          175                  인천광역시  수도권
# 177          176                  인천광역시  수도권
# 178          177                  인천광역시  수도권
# 179          178                  인천광역시  수도권
# 180          179                   전라남도  호남권
# 181          180                   전라남도  호남권
# 182          181                   전라남도  호남권
# 183          182                   전라남도  호남권
# 184          183                   전라남도  호남권
# 185          184                   전라남도  호남권
# 186          185                   전라남도  호남권
# 187          186                   전라남도  호남권
# 188          187                   전라남도  호남권
# 189          188                   전라남도  호남권
# 190          189                   전라남도  호남권
# 191          190                   전라남도  호남권
# 192          191                   전라남도  호남권
# 193          192                   전라남도  호남권
# 194          193                   전라남도  호남권
# 195          194                   전라남도  호남권
# 196          195                   전라남도  호남권
# 197          196                   전라남도  호남권
# 198          197                   전라남도  호남권
# 199          198                   전라남도  호남권
# 200          199                   전라남도  호남권
# 201          200                   전라남도  호남권
# 202          201                   전라남도  호남권
# 203          202                   전라북도  호남권
# 204          203                   전라북도  호남권
# 205          204                   전라북도  호남권
# 206          205                   전라북도  호남권
# 207          206                   전라북도  호남권
# 208          207                   전라북도  호남권
# 209          208                   전라북도  호남권
# 210          209                   전라북도  호남권
# 211          210                   전라북도  호남권
# 212          211                   전라북도  호남권
# 213          212                   전라북도  호남권
# 214          213                   전라북도  호남권
# 215          214                   전라북도  호남권
# 216          215                   전라북도  호남권
# 217          216                   전라북도  호남권
# 218          217                제주특별자치도   제주
# 219          220                제주특별자치도   제주
# 220          221                제주특별자치도   제주
# 221          222                   충청남도  충청권
# 222          223                   충청남도  충청권
# 223          224                   충청남도  충청권
# 224          225                   충청남도  충청권
# 225          226                   충청남도  충청권
# 226          227                   충청남도  충청권
# 227          228                   충청남도  충청권
# 228          229                   충청남도  충청권
# 229          230                   충청남도  충청권
# 230          231                   충청남도  충청권
# 231          233                   충청남도  충청권
# 232          234                   충청남도  충청권
# 233          235                   충청남도  충청권
# 234          236                   충청남도  충청권
# 235          237                   충청남도  충청권
# 236          238                   충청북도  충청권
# 237          239                   충청북도  충청권
# 238          240                   충청북도  충청권
# 239          241                   충청북도  충청권
# 240          242                   충청북도  충청권
# 241          243                   충청북도  충청권
# 242          244                   충청북도  충청권
# 243          245                   충청북도  충청권
# 244          246                   충청북도  충청권
# 245          248                   충청북도  충청권
# 246          249                   충청북도  충청권
# 247          250                   충청남도  충청권
# 248         6406                   충청북도  충청권
# 249         6474                세종특별자치시  충청권
# 250         6474                세종특별자치시  충청권
# 251         6487  임진강 수계지역(경기도 연천군,파주시)  수도권
# 252         6487  임진강 수계지역(경기도 연천군,파주시)  수도권

# %%
msg_location.columns=['location_id','location_sido','Area']
msg_location['location_id']=msg_location['location_id'].astype(str)
msg_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location_id    253 non-null    object
#  1   location_sido  253 non-null    object
#  2   Area           253 non-null    object
# dtypes: object(3)
# memory usage: 6.1+ KB

# %%
msg_location.to_csv("msg_location.csv", index=False)

# %% [markdown]
# ### total_msg와 합치기

# %%
msg_total=pd.read_csv('../safety_msg_crawling_total.csv')

# %%
msg_total['create_date']=pd.to_datetime(msg_total['create_date'])

# %%
msg_total=msg_total[msg_total['create_date']>='2020-01-23 15:08:34']
msg_total.head()
# Out:
#           create_date location_id location_name  md101_sn  \
# 0 2021-07-02 10:24:18         104      대구광역시 전체    110649
# 1 2021-07-02 10:22:59          98      광주광역시 전체    110648
# 2 2021-07-02 10:16:02          23       경기도 고양시    110647
# 3 2021-07-02 10:11:29          58      경상남도 남해군    110646
# 4 2021-07-02 10:09:23          26       경기도 광주시    110645
#
#                                                                                           msg  \
# 0    [대구광역시] 2일 0시 기준 확진자 9명(동구3 북구2 서구1 수성구1 달서구1 달성군1)발생. 의심시 외출 자제 및 가까운 보건소 예약 후 검사 바랍니다.
# 1    [광주광역시] 6.18.(금)~6.30.(수) 보보스(BOBOS)호프(북구 대자로 72-1, 운암동)에 방문하신 분은 거주지 보건소에서 검사받으시기 바랍니다.
# 2  [고양시청]7.1.(목) 일일 확진자 33명(덕양구9,일산동구14,일산서구9,타지역 거주1) ▶타지역확진 고양시민 2명 https://han.gl/iMmgw 참조
# 3      [남해군청]▶7.2.(금) 09:00기준 확진자 2명 발생 ( 자가격리 중 해제 전 검사 시 ) ▶관련정보는 남해군 홈페이지 또는 페이스북 참고 바랍니다.
# 4  [광주시청]제2차 광주시 재난기본소득(1인당 10만원) 미신청 하신 분은 7월말까지 주소지 읍면동사무소에서 신청바랍니다.(대상: 3.8.기준 광주시민,등록외국인)
#
#   send_platform
# 0           cbs
# 1           cbs
# 2           cbs
# 3           cbs
# 4           cbs

# %%
msg_location.set_index('location_id',inplace=True)
msg_total.set_index('location_id',inplace=True)

# %%
msg_total_id=msg_total.join(msg_location)
msg_total_id
# Out:
#                                        create_date  \
# location_id
# 10                             2021-06-27 10:23:41
# 10                             2021-06-24 19:47:20
# 10                             2021-05-24 09:34:44
# 10                             2021-05-22 12:13:45
# 10                             2021-05-04 13:11:21
# ...                                            ...
# 99,100,103,185,188,194,196,199 2020-07-13 08:02:46
# 99,100,185,188,194,199         2020-08-07 19:40:54
# 99,100,185,188,194,199         2020-08-07 16:39:21
# 99,100,185,188,194,199,201     2020-08-07 16:01:59
# 99,100,185,188,194,199,201     2020-08-07 15:17:08
#
#                                                                                            location_name  \
# location_id
# 10                                                                                               강원도 영월군
# 10                                                                                               강원도 영월군
# 10                                                                                               강원도 영월군
# 10                                                                                               강원도 영월군
# 10                                                                                               강원도 영월군
# ...                                                                                                  ...
# 99,100,103,185,188,194,196,199  광주광역시 광산구,광주광역시 남구,광주광역시 서구,전라남도 나주시,전라남도 무안군,전라남도 영암군,전라남도 장성군,전라남도 함평군
# 99,100,185,188,194,199                            광주광역시 광산구,광주광역시 남구,전라남도 나주시,전라남도 무안군,전라남도 영암군,전라남도 함평군
# 99,100,185,188,194,199                            광주광역시 광산구,광주광역시 남구,전라남도 나주시,전라남도 무안군,전라남도 영암군,전라남도 함평군
# 99,100,185,188,194,199,201               광주광역시 광산구,광주광역시 남구,전라남도 나주시,전라남도 무안군,전라남도 영암군,전라남도 함평군,전라남도 화순군
# 99,100,185,188,194,199,201               광주광역시 광산구,광주광역시 남구,전라남도 나주시,전라남도 무안군,전라남도 영암군,전라남도 함평군,전라남도 화순군
#
#                                 md101_sn  \
# location_id
# 10                                110127
# 10                                109933
# 10                                106650
# 10                                106466
# 10                                104167
# ...                                  ...
# 99,100,103,185,188,194,196,199     40493
# 99,100,185,188,194,199             42841
# 99,100,185,188,194,199             42757
# 99,100,185,188,194,199,201         42752
# 99,100,185,188,194,199,201         42734
#
#                                                                                                                       msg  \
# location_id
# 10                              [영월군청] 6/27(일) 확진자 영월읍 1명 발생(영월43번), 감염경로 역학조사 중 ▲코로나19 의심증상시 보건소 선별진료소에서 즉시 검사받으시기 바랍니다.
# 10                                                      [행정안전부] 오늘 19시45분 강원(영월) 호우주의보 발효. 대중교통을 이용하시고 빗길 안전에 주의하시기 바랍니다.
# 10                                          [영월군청]5.24.(월) 1명 확진(영월 41번), 역학조사 중이며, 이동 동선 등 세부사항은 홈페이지(yw.go.kr) 확인 바랍니다.
# 10                              [영월군청]5.22.(토) 1명 확진(영월 40번), 접촉자 파악 및 방역소독 완료, 관내 이동 동선 없으며 세부사항은 홈페이지(yw.go.kr) 참고바랍니다.
# 10                                    [영월군청]5.4.(화, 13시) 1명 확진(영월39번) 자가격리중으로 지역 내 이동 동선 없음. 세부사항은 홈페이지(yw.go.kr) 참고바랍니다.
# ...                                                                                                                   ...
# 99,100,103,185,188,194,196,199                                [영산강홍수통제소]오늘 08:00 황룡강 광주광역시(장록교) 홍수주의보 발령, 안전에 유의하시기 바랍니다.
# 99,100,185,188,194,199                                    [영산강홍수통제소]오늘 19:40 영산강 나주시(나주대교) 홍수경보 변경발령, 홍수피해 발생에 대비하시기 바랍니다
# 99,100,185,188,194,199                                         [영산강홍수통제소]오늘 16:40 영산강 나주시(나주대교) 홍수주의보 발령, 안전에 유의하시기 바랍니다.
# 99,100,185,188,194,199,201                                 [영산강홍수통제소]오늘 16:00 지석천 나주시(남평교) 홍수경보 변경발령, 홍수피해 발생에 대비하시기 바랍니다
# 99,100,185,188,194,199,201                                      [영산강홍수통제소]오늘 15:10 지석천 나주시(남평교) 홍수주의보 발령, 안전에 유의하시기 바랍니다.
#
#                                send_platform location_sido Area
# location_id
# 10                                       cbs           강원도  강원권
# 10                                       cbs           강원도  강원권
# 10                                       cbs           강원도  강원권
# 10                                       cbs           강원도  강원권
# 10                                       cbs           강원도  강원권
# ...                                      ...           ...  ...
# 99,100,103,185,188,194,196,199           cbs           NaN  NaN
# 99,100,185,188,194,199                   cbs           NaN  NaN
# 99,100,185,188,194,199                   cbs           NaN  NaN
# 99,100,185,188,194,199,201               cbs           NaN  NaN
# 99,100,185,188,194,199,201               cbs           NaN  NaN
#
# [90694 rows x 7 columns]

# %%
msg_total_id=msg_total_id.reset_index(drop=False)
msg_total_id.head()
# Out:
#   location_id         create_date location_name  md101_sn  \
# 0          10 2021-06-27 10:23:41       강원도 영월군    110127
# 1          10 2021-06-24 19:47:20       강원도 영월군    109933
# 2          10 2021-05-24 09:34:44       강원도 영월군    106650
# 3          10 2021-05-22 12:13:45       강원도 영월군    106466
# 4          10 2021-05-04 13:11:21       강원도 영월군    104167
#
#                                                                                          msg  \
# 0  [영월군청] 6/27(일) 확진자 영월읍 1명 발생(영월43번), 감염경로 역학조사 중 ▲코로나19 의심증상시 보건소 선별진료소에서 즉시 검사받으시기 바랍니다.
# 1                          [행정안전부] 오늘 19시45분 강원(영월) 호우주의보 발효. 대중교통을 이용하시고 빗길 안전에 주의하시기 바랍니다.
# 2              [영월군청]5.24.(월) 1명 확진(영월 41번), 역학조사 중이며, 이동 동선 등 세부사항은 홈페이지(yw.go.kr) 확인 바랍니다.
# 3  [영월군청]5.22.(토) 1명 확진(영월 40번), 접촉자 파악 및 방역소독 완료, 관내 이동 동선 없으며 세부사항은 홈페이지(yw.go.kr) 참고바랍니다.
# 4        [영월군청]5.4.(화, 13시) 1명 확진(영월39번) 자가격리중으로 지역 내 이동 동선 없음. 세부사항은 홈페이지(yw.go.kr) 참고바랍니다.
#
#   send_platform location_sido Area
# 0           cbs           강원도  강원권
# 1           cbs           강원도  강원권
# 2           cbs           강원도  강원권
# 3           cbs           강원도  강원권
# 4           cbs           강원도  강원권

# %%
msg_total_id['Area'].isnull().sum()
# Out:
# 1099

# %%
msg_total_id.to_csv("msg_total_id.csv", index=False)

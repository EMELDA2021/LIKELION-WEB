# %%
from IPython.display import display, Image
import os, warnings
import re
warnings.filterwarnings(action='ignore')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
driver = webdriver.Chrome('../chromedriver_90')
url = 'https://www.safekorea.go.kr/idsiSFK/neo/sfk/cs/sfc/dis/disasterMsgList.jsp?emgPage=Y&menuSeq=679'
driver.get(url)
import time
time.sleep(3) # 홈페이지 로딩 시간 3초

# %%
sel_select=driver.find_element_by_xpath('//*[@id="search_type_v"]/option[2]')
sel_select.click()

# %%
sel_input=driver.find_element_by_xpath('//*[@id="search_val_v"]')
sel_input.clear()
sel_input.send_keys('코로나 검사')

# %%
sel_start=driver.find_element_by_xpath('//*[@id="search_start"]')
sel_start.clear()
sel_start.send_keys('20210501')

# %%
sel_end=driver.find_element_by_xpath('//*[@id="search_end"]')
sel_end.clear()
sel_end.send_keys('20210531')

# %%
sel_search_btn=driver.find_element_by_xpath('//*[@id="content"]/div[1]/a')
sel_search_btn.click()

# %% [markdown]
# 반복:글 제목>크롤링>페이지넘기기

# %%
one_list=driver.find_element_by_xpath('//*[@id="bbs_tr"]')
num=driver.find_element_by_xpath('//*[@id="bbs_tr_0_num_td"]').text
print("글의 갯수는?",num)
# Out:
# 글의 갯수는? 52

# %%
sel_num=driver.find_element_by_xpath('//*[@id="bbs_tr_0_bbs_title"]').text.split(' ')
print(sel_num[0])
print(sel_num[1])
print(sel_num[2].strip('재난문자'))
# Out:
# 2021/05/31
# 09:51:02
# [포항시청]

# %%
page_num=driver.find_element_by_xpath('//*[@id="maxPage"]').text
print("페이수는?",page_num)
# Out:
# 페이수는? 6

# %%
all_date=[]
all_time=[]
all_area=[]
count=0
while count < (int(num)+1):        
    for i in range(1,(int(page_num)+1)):
        page_input=driver.find_element_by_xpath('//*[@id="bbs_page"]')
        page_input.clear()
        page_input.send_keys(f'{i}')
        page_click=driver.find_element_by_xpath('//*[@id="content"]/div[4]/div/a[3]')
        page_click.click()
        time.sleep(3)
        
        for i in range(0,10):    
            count+=1
            if count > int(num):
                break
            one_list=driver.find_element_by_xpath('//*[@id="bbs_tr"]')
            tmp=f'//*[@id="bbs_tr_{i}_bbs_title"]'
        
            sel_num=driver.find_element_by_xpath(tmp).text.split(' ')
            all_date.append(sel_num[0])
            all_time.append(sel_num[1])
            all_area.append(sel_num[2].strip('재난문자'))
    time.sleep(3)
    try:    
        pass
    except NoSuchElementException or StaleElementReferenceException:
        pass
    
print(count)
print(len(all_date))
print(len(all_time))
print(len(all_area))
print(all_date)
# Out:
# 53
# 52
# 52
# 52
# ['2021/05/31', '2021/05/30', '2021/05/30', '2021/05/30', '2021/05/30', '2021/05/29', '2021/05/29', '2021/05/29', '2021/05/28', '2021/05/28', '2021/05/28', '2021/05/28', '2021/05/28', '2021/05/27', '2021/05/26', '2021/05/26', '2021/05/25', '2021/05/24', '2021/05/24', '2021/05/23', '2021/05/23', '2021/05/22', '2021/05/21', '2021/05/20', '2021/05/20', '2021/05/20', '2021/05/19', '2021/05/18', '2021/05/18', '2021/05/17', '2021/05/17', '2021/05/15', '2021/05/15', '2021/05/14', '2021/05/14', '2021/05/14', '2021/05/13', '2021/05/13', '2021/05/11', '2021/05/10', '2021/05/10', '2021/05/09', '2021/05/09', '2021/05/07', '2021/05/07', '2021/05/07', '2021/05/06', '2021/05/04', '2021/05/04', '2021/05/04', '2021/05/03', '2021/05/02']

# %% [markdown]
# 자료 변환

# %%
import pandas as pd

# %%
dict_dat={'날짜':all_date,'시간':all_time,'지역':all_area}
dat = pd.DataFrame(dict_dat)
dat
# Out:
#             날짜        시간       지역
# 0   2021/05/31  09:51:02   [포항시청]
# 1   2021/05/30  15:42:24   [고양시청]
# 2   2021/05/30  15:39:59   [고양시청]
# 3   2021/05/30  15:03:43   [김해시청]
# 4   2021/05/30  13:06:45   [고양시청]
# 5   2021/05/29  17:52:59   [음성군청]
# 6   2021/05/29  11:54:23   [아산시청]
# 7   2021/05/29  09:12:35   [서천군청]
# 8   2021/05/28  20:51:52   [고양시청]
# 9   2021/05/28  20:45:12   [고양시청]
# 10  2021/05/28  20:33:26   [고양시청]
# 11  2021/05/28  19:55:22   [함평군청]
# 12  2021/05/28  19:54:32   [함평군청]
# 13  2021/05/27  17:13:42   [김해시청]
# 14  2021/05/26  15:16:41   [금천구청]
# 15  2021/05/26  09:11:35   [김해시청]
# 16  2021/05/25  15:53:54   [남동구청]
# 17  2021/05/24  10:55:19   [아산시청]
# 18  2021/05/24  10:54:27   [아산시청]
# 19  2021/05/23  17:42:35   [김해시청]
# 20  2021/05/23  13:39:40   [아산시청]
# 21  2021/05/22  12:45:55   [고양시청]
# 22  2021/05/21  17:33:36   [김해시청]
# 23  2021/05/20  18:49:11   [함평군청]
# 24  2021/05/20  15:10:06   [아산시청]
# 25  2021/05/20  13:46:40   [노원구청]
# 26  2021/05/19  14:04:39   [함평군청]
# 27  2021/05/18  14:45:02   [아산시청]
# 28  2021/05/18  13:40:10   [아산시청]
# 29  2021/05/17  19:24:53   [부천시청]
# 30  2021/05/17  14:59:47   [노원구청]
# 31  2021/05/15  18:55:31   [김해시청]
# 32  2021/05/15  13:53:15   [함평군청]
# 33  2021/05/14  13:46:25  [의정부시청]
# 34  2021/05/14  11:00:37   [구례군청]
# 35  2021/05/14  09:17:16   [안동시청]
# 36  2021/05/13  20:52:13   [고양시청]
# 37  2021/05/13  11:47:08   [부여군청]
# 38  2021/05/11  09:37:18   [천안시청]
# 39  2021/05/10  19:25:47   [부여군청]
# 40  2021/05/10  13:45:07   [부여군청]
# 41  2021/05/09  11:37:10   [부여군청]
# 42  2021/05/09  08:04:48   [고흥군청]
# 43  2021/05/07  15:57:50   [고령군청]
# 44  2021/05/07  15:42:58  [광주광역시]
# 45  2021/05/07  13:41:53   [음성군청]
# 46  2021/05/06  19:28:11   [고양시청]
# 47  2021/05/04  16:27:03   [고양시청]
# 48  2021/05/04  13:44:25   [도봉구청]
# 49  2021/05/04  09:11:35   [김해시청]
# 50  2021/05/03  15:22:24   [노원구청]
# 51  2021/05/02  13:46:17   [인제군청]

# %%
dat.to_csv("alarm_5.csv", index=False)
os.listdir( os.getcwd() )
# Out:
# ['.ipynb_checkpoints',
#  '0701_alarm_text_5.ipynb',
#  '0701_alarm_text_6.ipynb',
#  '0701_chungking_express.ipynb',
#  '0701_konlpy.ipynb',
#  '0701_public_data.ipynb',
#  'alarm_5.csv',
#  'alarm_6.csv',
#  'can.jpg',
#  'chungking_express.csv',
#  'chunking_express.jpg',
#  'stopwords_ko.txt']
